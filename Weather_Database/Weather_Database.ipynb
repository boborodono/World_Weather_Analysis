# %%
# Import dependencies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from citipy import citipy
import requests
import time
from datetime import datetime

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 719

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Description added to 
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | college
# Processing Record 2 of Set 1 | bandarbeyla
# Processing Record 3 of Set 1 | bilibino
# Processing Record 4 of Set 1 | beringovskiy
# Processing Record 5 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 1 | saint-philippe
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | cayenne
# Processing Record 9 of Set 1 | yellowknife
# Processing Record 10 of Set 1 | uwayl
# City not found. Skipping...
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | qaanaaq
# Processing Record 14 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 15 of Set 1 | cidreira
# Processing Record 16 of Set 1 | ostersund
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 1 | puerto ayora
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | castro
# Processing Record 23 of Set 1 | katsuura
# Processing Record 24 of Set 1 | hermanus
# Processing Record 25 of Set 1 | torbay
# Processing Record 26 of Set 1 | coquimbo
# Processing Record 27 of Set 1 | hithadhoo
# Processing Record 28 of Set 1 | haines junction
# Processing Record 29 of Set 1 | saint-pierre
# Processing Record 30 of Set 1 | karauzyak
# City not found. Skipping...
# Processing Record 31 of Set 1 | muravlenko
# Processing Record 32 of Set 1 | tambopata
# Processing Record 33 of Set 1 | butaritari
# Processing Record 34 of Set 1 | angoram
# Processing Record 35 of Set 1 | lebu
# Processing Record 36 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 1 | baicheng
# Processing Record 38 of Set 1 | turukhansk
# Processing Record 39 of Set 1 | cherskiy
# Processing Record 40 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 41 of Set 1 | nizhniy kuranakh
# Processing Record 42 of Set 1 | clyde river
# Processing Record 43 of Set 1 | topalu
# Processing Record 44 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 1 | glasgow
# Processing Record 46 of Set 1 | leningradskiy
# Processing Record 47 of Set 1 | avarua
# Processing Record 48 of Set 1 | chapada dos guimaraes
# Processing Record 49 of Set 1 | port alfred
# Processing Record 50 of Set 1 | albany
# Processing Record 1 of Set 2 | arraial do cabo
# Processing Record 2 of Set 2 | nanortalik
# Processing Record 3 of Set 2 | port elizabeth
# Processing Record 4 of Set 2 | half moon bay
# Processing Record 5 of Set 2 | tasiilaq
# Processing Record 6 of Set 2 | new norfolk
# Processing Record 7 of Set 2 | tashara
# Processing Record 8 of Set 2 | rutul
# Processing Record 9 of Set 2 | ciudad bolivar
# Processing Record 10 of Set 2 | pevek
# Processing Record 11 of Set 2 | jaca
# Processing Record 12 of Set 2 | monrovia
# Processing Record 13 of Set 2 | barrow
# Processing Record 14 of Set 2 | mayumba
# Processing Record 15 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 2 | necochea
# Processing Record 17 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 18 of Set 2 | georgetown
# Processing Record 19 of Set 2 | inta
# Processing Record 20 of Set 2 | sao filipe
# Processing Record 21 of Set 2 | istok
# Processing Record 22 of Set 2 | athni
# Processing Record 23 of Set 2 | zacatecoluca
# Processing Record 24 of Set 2 | saldanha
# Processing Record 25 of Set 2 | bredasdorp
# Processing Record 26 of Set 2 | yumen
# Processing Record 27 of Set 2 | jamestown
# Processing Record 28 of Set 2 | victor harbor
# Processing Record 29 of Set 2 | kahului
# Processing Record 30 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 31 of Set 2 | fagernes
# Processing Record 32 of Set 2 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 33 of Set 2 | masty
# Processing Record 34 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 2 | kruisfontein
# Processing Record 36 of Set 2 | aleysk
# Processing Record 37 of Set 2 | tuktoyaktuk
# Processing Record 38 of Set 2 | kapaa
# Processing Record 39 of Set 2 | polyarnyye zori
# Processing Record 40 of Set 2 | taldan
# Processing Record 41 of Set 2 | sitka
# Processing Record 42 of Set 2 | guicheng
# City not found. Skipping...
# Processing Record 43 of Set 2 | petit goave
# Processing Record 44 of Set 2 | melukote
# Processing Record 45 of Set 2 | hilo
# Processing Record 46 of Set 2 | den helder
# Processing Record 47 of Set 2 | mahebourg
# Processing Record 48 of Set 2 | punta arenas
# Processing Record 49 of Set 2 | kodiak
# Processing Record 50 of Set 2 | bonanza
# Processing Record 1 of Set 3 | narsaq
# Processing Record 2 of Set 3 | atuona
# Processing Record 3 of Set 3 | bubaque
# Processing Record 4 of Set 3 | mana
# Processing Record 5 of Set 3 | bluff
# Processing Record 6 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 3 | bom jesus
# Processing Record 8 of Set 3 | araria
# Processing Record 9 of Set 3 | dikson
# Processing Record 10 of Set 3 | tuatapere
# Processing Record 11 of Set 3 | hambantota
# Processing Record 12 of Set 3 | klaksvik
# Processing Record 13 of Set 3 | ballina
# Processing Record 14 of Set 3 | karamea
# City not found. Skipping...
# Processing Record 15 of Set 3 | u thong
# Processing Record 16 of Set 3 | bambous virieux
# Processing Record 17 of Set 3 | hegang
# Processing Record 18 of Set 3 | lagoa
# Processing Record 19 of Set 3 | yankton
# Processing Record 20 of Set 3 | hobart
# Processing Record 21 of Set 3 | rocha
# Processing Record 22 of Set 3 | morehead
# Processing Record 23 of Set 3 | bethel
# Processing Record 24 of Set 3 | broome
# Processing Record 25 of Set 3 | tulun
# Processing Record 26 of Set 3 | nikolskoye
# Processing Record 27 of Set 3 | verkh-usugli
# Processing Record 28 of Set 3 | borogontsy
# Processing Record 29 of Set 3 | alofi
# Processing Record 30 of Set 3 | bilma
# Processing Record 31 of Set 3 | villa union
# Processing Record 32 of Set 3 | ponta do sol
# Processing Record 33 of Set 3 | maragogi
# Processing Record 34 of Set 3 | urdzhar
# City not found. Skipping...
# Processing Record 35 of Set 3 | san cristobal
# Processing Record 36 of Set 3 | puerto escondido
# Processing Record 37 of Set 3 | lazarev
# Processing Record 38 of Set 3 | sola
# Processing Record 39 of Set 3 | dayong
# Processing Record 40 of Set 3 | eureka
# Processing Record 41 of Set 3 | severo-kurilsk
# Processing Record 42 of Set 3 | tongren
# Processing Record 43 of Set 3 | kommunar
# Processing Record 44 of Set 3 | byron bay
# Processing Record 45 of Set 3 | labuhan
# Processing Record 46 of Set 3 | peniche
# Processing Record 47 of Set 3 | palmer
# Processing Record 48 of Set 3 | grindavik
# Processing Record 49 of Set 3 | provideniya
# Processing Record 50 of Set 3 | saint george
# Processing Record 1 of Set 4 | fort nelson
# Processing Record 2 of Set 4 | axim
# Processing Record 3 of Set 4 | nadym
# Processing Record 4 of Set 4 | dingle
# Processing Record 5 of Set 4 | urfa
# City not found. Skipping...
# Processing Record 6 of Set 4 | namibe
# Processing Record 7 of Set 4 | lovozero
# Processing Record 8 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 9 of Set 4 | smithers
# Processing Record 10 of Set 4 | pacific grove
# Processing Record 11 of Set 4 | upernavik
# Processing Record 12 of Set 4 | yulara
# Processing Record 13 of Set 4 | bahia blanca
# Processing Record 14 of Set 4 | fernandez
# Processing Record 15 of Set 4 | muscat
# Processing Record 16 of Set 4 | kalakamati
# Processing Record 17 of Set 4 | kaitangata
# Processing Record 18 of Set 4 | zhigansk
# Processing Record 19 of Set 4 | lavrentiya
# Processing Record 20 of Set 4 | kadoma
# Processing Record 21 of Set 4 | port hardy
# Processing Record 22 of Set 4 | erenhot
# Processing Record 23 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 4 | ribeira grande
# Processing Record 25 of Set 4 | harlingen
# Processing Record 26 of Set 4 | gerash
# Processing Record 27 of Set 4 | tabou
# Processing Record 28 of Set 4 | mount gambier
# Processing Record 29 of Set 4 | vestmannaeyjar
# Processing Record 30 of Set 4 | los llanos de aridane
# Processing Record 31 of Set 4 | swan river
# Processing Record 32 of Set 4 | auki
# Processing Record 33 of Set 4 | fort morgan
# Processing Record 34 of Set 4 | mackay
# Processing Record 35 of Set 4 | ribnica
# Processing Record 36 of Set 4 | macaboboni
# City not found. Skipping...
# Processing Record 37 of Set 4 | codrington
# Processing Record 38 of Set 4 | saint-georges
# Processing Record 39 of Set 4 | hobyo
# Processing Record 40 of Set 4 | haverfordwest
# Processing Record 41 of Set 4 | besikduzu
# Processing Record 42 of Set 4 | buala
# Processing Record 43 of Set 4 | jaru
# Processing Record 44 of Set 4 | nova russas
# Processing Record 45 of Set 4 | port-gentil
# Processing Record 46 of Set 4 | sao joao da barra
# Processing Record 47 of Set 4 | coihaique
# Processing Record 48 of Set 4 | puerto del rosario
# Processing Record 49 of Set 4 | lata
# Processing Record 50 of Set 4 | tura
# Processing Record 1 of Set 5 | ilulissat
# Processing Record 2 of Set 5 | yarim
# Processing Record 3 of Set 5 | biak
# Processing Record 4 of Set 5 | aasiaat
# Processing Record 5 of Set 5 | touros
# Processing Record 6 of Set 5 | oranjestad
# Processing Record 7 of Set 5 | barberton
# Processing Record 8 of Set 5 | batagay
# Processing Record 9 of Set 5 | yeniseysk
# Processing Record 10 of Set 5 | udachnyy
# Processing Record 11 of Set 5 | thompson
# Processing Record 12 of Set 5 | mooi river
# City not found. Skipping...
# Processing Record 13 of Set 5 | vila velha
# Processing Record 14 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 5 | alice springs
# Processing Record 16 of Set 5 | lorengau
# Processing Record 17 of Set 5 | khuzhir
# Processing Record 18 of Set 5 | puerto carreno
# Processing Record 19 of Set 5 | fernie
# Processing Record 20 of Set 5 | sangar
# Processing Record 21 of Set 5 | guerrero negro
# Processing Record 22 of Set 5 | khatanga
# Processing Record 23 of Set 5 | piryetos
# City not found. Skipping...
# Processing Record 24 of Set 5 | stepnoye
# Processing Record 25 of Set 5 | muroto
# Processing Record 26 of Set 5 | faya
# Processing Record 27 of Set 5 | shinshiro
# Processing Record 28 of Set 5 | esperance
# Processing Record 29 of Set 5 | karratha
# Processing Record 30 of Set 5 | ijaki
# City not found. Skipping...
# Processing Record 31 of Set 5 | paamiut
# Processing Record 32 of Set 5 | atikokan
# Processing Record 33 of Set 5 | longyearbyen
# Processing Record 34 of Set 5 | kerki
# City not found. Skipping...
# Processing Record 35 of Set 5 | xuddur
# Processing Record 36 of Set 5 | mastic beach
# Processing Record 37 of Set 5 | lota
# Processing Record 38 of Set 5 | comodoro rivadavia
# Processing Record 39 of Set 5 | atambua
# Processing Record 40 of Set 5 | kathmandu
# Processing Record 41 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 43 of Set 5 | panjab
# Processing Record 44 of Set 5 | sanchor
# Processing Record 45 of Set 5 | ploemeur
# Processing Record 46 of Set 5 | along
# Processing Record 47 of Set 5 | caravelas
# Processing Record 48 of Set 5 | san patricio
# Processing Record 49 of Set 5 | bonavista
# Processing Record 50 of Set 5 | bonthe
# Processing Record 1 of Set 6 | saint-joseph
# Processing Record 2 of Set 6 | saint anthony
# Processing Record 3 of Set 6 | chunskiy
# Processing Record 4 of Set 6 | port keats
# Processing Record 5 of Set 6 | namtsy
# Processing Record 6 of Set 6 | taveta
# Processing Record 7 of Set 6 | ravar
# Processing Record 8 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 6 | yaan
# Processing Record 11 of Set 6 | adrar
# Processing Record 12 of Set 6 | bayangol
# Processing Record 13 of Set 6 | la palma
# Processing Record 14 of Set 6 | tazovskiy
# Processing Record 15 of Set 6 | ibra
# Processing Record 16 of Set 6 | juprelle
# Processing Record 17 of Set 6 | kiunga
# Processing Record 18 of Set 6 | nemuro
# Processing Record 19 of Set 6 | isangel
# Processing Record 20 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 6 | boyolangu
# Processing Record 22 of Set 6 | kintinku
# Processing Record 23 of Set 6 | salinopolis
# Processing Record 24 of Set 6 | puerto el triunfo
# Processing Record 25 of Set 6 | brae
# Processing Record 26 of Set 6 | garden city
# Processing Record 27 of Set 6 | chuy
# Processing Record 28 of Set 6 | jacareacanga
# Processing Record 29 of Set 6 | sambava
# Processing Record 30 of Set 6 | sabaudia
# Processing Record 31 of Set 6 | castrillon
# Processing Record 32 of Set 6 | agirish
# Processing Record 33 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 34 of Set 6 | alta floresta
# Processing Record 35 of Set 6 | avera
# Processing Record 36 of Set 6 | canutama
# Processing Record 37 of Set 6 | nyamuswa
# Processing Record 38 of Set 6 | ilheus
# Processing Record 39 of Set 6 | saint-louis
# Processing Record 40 of Set 6 | marawi
# Processing Record 41 of Set 6 | matara
# Processing Record 42 of Set 6 | cururupu
# Processing Record 43 of Set 6 | yarensk
# Processing Record 44 of Set 6 | vicente guerrero
# Processing Record 45 of Set 6 | saskylakh
# Processing Record 46 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 6 | bombay
# Processing Record 48 of Set 6 | gainesville
# Processing Record 49 of Set 6 | beloha
# Processing Record 50 of Set 6 | nazas
# Processing Record 1 of Set 7 | geraldton
# Processing Record 2 of Set 7 | vao
# Processing Record 3 of Set 7 | terra nova
# Processing Record 4 of Set 7 | kamenka
# Processing Record 5 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 6 of Set 7 | sangmelima
# Processing Record 7 of Set 7 | glendive
# Processing Record 8 of Set 7 | reconquista
# Processing Record 9 of Set 7 | quang ngai
# Processing Record 10 of Set 7 | englewood
# Processing Record 11 of Set 7 | constitucion
# Processing Record 12 of Set 7 | ialibu
# Processing Record 13 of Set 7 | siniscola
# Processing Record 14 of Set 7 | pisco
# Processing Record 15 of Set 7 | hasaki
# Processing Record 16 of Set 7 | olavarria
# Processing Record 17 of Set 7 | broken hill
# Processing Record 18 of Set 7 | lima
# Processing Record 19 of Set 7 | ios
# Processing Record 20 of Set 7 | nelson bay
# Processing Record 21 of Set 7 | viedma
# Processing Record 22 of Set 7 | krasnyy kholm
# Processing Record 23 of Set 7 | la ronge
# Processing Record 24 of Set 7 | yar-sale
# Processing Record 25 of Set 7 | hohhot
# Processing Record 26 of Set 7 | hamilton
# Processing Record 27 of Set 7 | mount isa
# Processing Record 28 of Set 7 | iquique
# Processing Record 29 of Set 7 | obidos
# Processing Record 30 of Set 7 | general pico
# Processing Record 31 of Set 7 | sun city west
# Processing Record 32 of Set 7 | amapa
# Processing Record 33 of Set 7 | payo
# Processing Record 34 of Set 7 | daru
# Processing Record 35 of Set 7 | carnarvon
# Processing Record 36 of Set 7 | faanui
# Processing Record 37 of Set 7 | acarau
# Processing Record 38 of Set 7 | basco
# Processing Record 39 of Set 7 | panzhihua
# Processing Record 40 of Set 7 | slave lake
# Processing Record 41 of Set 7 | maltahohe
# Processing Record 42 of Set 7 | springdale
# Processing Record 43 of Set 7 | bertinoro
# Processing Record 44 of Set 7 | rosia de amaradia
# Processing Record 45 of Set 7 | marsh harbour
# Processing Record 46 of Set 7 | kailua
# Processing Record 47 of Set 7 | kaeo
# Processing Record 48 of Set 7 | tomatlan
# Processing Record 49 of Set 7 | gilgit
# Processing Record 50 of Set 7 | kegayli
# City not found. Skipping...
# Processing Record 1 of Set 8 | catabola
# Processing Record 2 of Set 8 | yibin
# Processing Record 3 of Set 8 | rudbar
# Processing Record 4 of Set 8 | indian head
# Processing Record 5 of Set 8 | novoukrayinka
# Processing Record 6 of Set 8 | pandan
# Processing Record 7 of Set 8 | lakes entrance
# Processing Record 8 of Set 8 | tautira
# Processing Record 9 of Set 8 | baruun-urt
# Processing Record 10 of Set 8 | jertih
# Processing Record 11 of Set 8 | roma
# Processing Record 12 of Set 8 | lobito
# Processing Record 13 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 8 | tilichiki
# Processing Record 15 of Set 8 | nuristan
# Processing Record 16 of Set 8 | saint-francois
# Processing Record 17 of Set 8 | aykhal
# Processing Record 18 of Set 8 | tay ninh
# Processing Record 19 of Set 8 | ampanihy
# Processing Record 20 of Set 8 | hualmay
# Processing Record 21 of Set 8 | padang
# Processing Record 22 of Set 8 | banyo
# Processing Record 23 of Set 8 | timiryazevskiy
# Processing Record 24 of Set 8 | bud
# Processing Record 25 of Set 8 | camacha
# Processing Record 26 of Set 8 | kazerun
# Processing Record 27 of Set 8 | luderitz
# Processing Record 28 of Set 8 | vangaindrano
# Processing Record 29 of Set 8 | teguise
# Processing Record 30 of Set 8 | shimoda
# Processing Record 31 of Set 8 | nata
# Processing Record 32 of Set 8 | dalvik
# Processing Record 33 of Set 8 | deniliquin
# Processing Record 34 of Set 8 | hammerfest
# Processing Record 35 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 36 of Set 8 | bengkulu
# Processing Record 37 of Set 8 | havre-saint-pierre
# Processing Record 38 of Set 8 | excelsior springs
# Processing Record 39 of Set 8 | manokwari
# Processing Record 40 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 41 of Set 8 | talipan
# Processing Record 42 of Set 8 | lesnyye polyany
# Processing Record 43 of Set 8 | moerai
# Processing Record 44 of Set 8 | lasa
# Processing Record 45 of Set 8 | bathsheba
# Processing Record 46 of Set 8 | sertania
# Processing Record 47 of Set 8 | tahe
# Processing Record 48 of Set 8 | bolshaya glushitsa
# Processing Record 49 of Set 8 | cap malheureux
# Processing Record 50 of Set 8 | lanigan
# Processing Record 1 of Set 9 | businga
# Processing Record 2 of Set 9 | olafsvik
# Processing Record 3 of Set 9 | dauphin
# Processing Record 4 of Set 9 | forio
# Processing Record 5 of Set 9 | jumla
# Processing Record 6 of Set 9 | mar del plata
# Processing Record 7 of Set 9 | praia da vitoria
# Processing Record 8 of Set 9 | lompoc
# Processing Record 9 of Set 9 | manikchhari
# City not found. Skipping...
# Processing Record 10 of Set 9 | cabo san lucas
# Processing Record 11 of Set 9 | cariamanga
# Processing Record 12 of Set 9 | hatsukaichi
# Processing Record 13 of Set 9 | xacmaz
# Processing Record 14 of Set 9 | constantine
# Processing Record 15 of Set 9 | victoria
# Processing Record 16 of Set 9 | korla
# Processing Record 17 of Set 9 | yinchuan
# Processing Record 18 of Set 9 | ornskoldsvik
# Processing Record 19 of Set 9 | svetlyy
# Processing Record 20 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 9 | jining
# Processing Record 22 of Set 9 | bossembele
# City not found. Skipping...
# Processing Record 23 of Set 9 | verkhnyaya inta
# Processing Record 24 of Set 9 | allapalli
# Processing Record 25 of Set 9 | iqaluit
# Processing Record 26 of Set 9 | chokurdakh
# Processing Record 27 of Set 9 | singaraja
# Processing Record 28 of Set 9 | sorland
# Processing Record 29 of Set 9 | port blair
# Processing Record 30 of Set 9 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 31 of Set 9 | hami
# Processing Record 32 of Set 9 | gillette
# Processing Record 33 of Set 9 | riyadh
# Processing Record 34 of Set 9 | grand gaube
# Processing Record 35 of Set 9 | srednekolymsk
# Processing Record 36 of Set 9 | bandundu
# Processing Record 37 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 38 of Set 9 | paragominas
# Processing Record 39 of Set 9 | san borja
# Processing Record 40 of Set 9 | coromandel
# Processing Record 41 of Set 9 | ugoofaaru
# Processing Record 42 of Set 9 | tessalit
# Processing Record 43 of Set 9 | kabalo
# Processing Record 44 of Set 9 | porto murtinho
# Processing Record 45 of Set 9 | antalaha
# Processing Record 46 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 47 of Set 9 | kalmunai
# Processing Record 48 of Set 9 | miandrivazo
# Processing Record 49 of Set 9 | kangaatsiaq
# Processing Record 50 of Set 9 | kyaiklat
# Processing Record 1 of Set 10 | norman wells
# Processing Record 2 of Set 10 | mutsu
# Processing Record 3 of Set 10 | kachikau
# City not found. Skipping...
# Processing Record 4 of Set 10 | catemaco
# Processing Record 5 of Set 10 | itamaraca
# Processing Record 6 of Set 10 | larsnes
# Processing Record 7 of Set 10 | albion
# Processing Record 8 of Set 10 | nakhon si thammarat
# Processing Record 9 of Set 10 | hohoe
# Processing Record 10 of Set 10 | sinkat
# City not found. Skipping...
# Processing Record 11 of Set 10 | rundu
# Processing Record 12 of Set 10 | tiksi
# Processing Record 13 of Set 10 | mikuni
# Processing Record 14 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 15 of Set 10 | port lincoln
# Processing Record 16 of Set 10 | iberia
# Processing Record 17 of Set 10 | weligama
# Processing Record 18 of Set 10 | yanan
# City not found. Skipping...
# Processing Record 19 of Set 10 | manta
# Processing Record 20 of Set 10 | hervey bay
# Processing Record 21 of Set 10 | camana
# Processing Record 22 of Set 10 | tailai
# Processing Record 23 of Set 10 | komsomolskiy
# Processing Record 24 of Set 10 | ambilobe
# Processing Record 25 of Set 10 | piopio
# Processing Record 26 of Set 10 | elko
# Processing Record 27 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 10 | addis zemen
# City not found. Skipping...
# Processing Record 29 of Set 10 | poum
# Processing Record 30 of Set 10 | the pas
# Processing Record 31 of Set 10 | bodmin
# Processing Record 32 of Set 10 | felidhoo
# City not found. Skipping...
# Processing Record 33 of Set 10 | guarda
# Processing Record 34 of Set 10 | linjiang
# Processing Record 35 of Set 10 | ulladulla
# Processing Record 36 of Set 10 | cascais
# Processing Record 37 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 10 | fare
# Processing Record 39 of Set 10 | henties bay
# Processing Record 40 of Set 10 | te anau
# Processing Record 41 of Set 10 | ahipara
# Processing Record 42 of Set 10 | fortuna
# Processing Record 43 of Set 10 | santarem
# Processing Record 44 of Set 10 | northam
# Processing Record 45 of Set 10 | lagos
# Processing Record 46 of Set 10 | airai
# Processing Record 47 of Set 10 | valle de allende
# Processing Record 48 of Set 10 | tezu
# Processing Record 49 of Set 10 | alyangula
# Processing Record 50 of Set 10 | ancud
# Processing Record 1 of Set 11 | laguna
# Processing Record 2 of Set 11 | maraba
# Processing Record 3 of Set 11 | praia
# Processing Record 4 of Set 11 | chengde
# Processing Record 5 of Set 11 | chumikan
# Processing Record 6 of Set 11 | kashi
# Processing Record 7 of Set 11 | zabol
# Processing Record 8 of Set 11 | coahuayana
# Processing Record 9 of Set 11 | aktau
# Processing Record 10 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 11 | codajas
# Processing Record 12 of Set 11 | chifeng
# Processing Record 13 of Set 11 | humaita
# Processing Record 14 of Set 11 | ha tinh
# Processing Record 15 of Set 11 | rujewa
# Processing Record 16 of Set 11 | salekhard
# Processing Record 17 of Set 11 | berlevag
# Processing Record 18 of Set 11 | ulsteinvik
# Processing Record 19 of Set 11 | kaset sombun
# Processing Record 20 of Set 11 | talnakh
# Processing Record 21 of Set 11 | tsaratanana
# Processing Record 22 of Set 11 | dharmadam
# Processing Record 23 of Set 11 | burnie
# Processing Record 24 of Set 11 | ouango
# Processing Record 25 of Set 11 | coronado
# Processing Record 26 of Set 11 | pangai
# Processing Record 27 of Set 11 | ketchikan
# Processing Record 28 of Set 11 | amga
# Processing Record 29 of Set 11 | jamsa
# Processing Record 30 of Set 11 | vorchdorf
# Processing Record 31 of Set 11 | richards bay
# Processing Record 32 of Set 11 | wanning
# Processing Record 33 of Set 11 | manzhouli
# Processing Record 34 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 35 of Set 11 | ormara
# Processing Record 36 of Set 11 | lebanon
# Processing Record 37 of Set 11 | vero beach
# Processing Record 38 of Set 11 | shaowu
# Processing Record 39 of Set 11 | makakilo city
# Processing Record 40 of Set 11 | bolshaya rechka
# Processing Record 41 of Set 11 | tuckahoe
# Processing Record 42 of Set 11 | pangnirtung
# Processing Record 43 of Set 11 | popondetta
# Processing Record 44 of Set 11 | siverek
# Processing Record 45 of Set 11 | ballarat
# Processing Record 46 of Set 11 | east london
# Processing Record 47 of Set 11 | kuopio
# Processing Record 48 of Set 11 | saint-augustin
# Processing Record 49 of Set 11 | tual
# Processing Record 50 of Set 11 | sabha
# Processing Record 1 of Set 12 | fort madison
# Processing Record 2 of Set 12 | antofagasta
# Processing Record 3 of Set 12 | leshukonskoye
# Processing Record 4 of Set 12 | kars
# Processing Record 5 of Set 12 | souillac
# Processing Record 6 of Set 12 | teknaf
# Processing Record 7 of Set 12 | disna
# Processing Record 8 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 9 of Set 12 | changji
# Processing Record 10 of Set 12 | araguaina
# Processing Record 11 of Set 12 | pailon
# Processing Record 12 of Set 12 | mandurah
# Processing Record 13 of Set 12 | vardo
# Processing Record 14 of Set 12 | fairbanks
# Processing Record 15 of Set 12 | karasjok
# Processing Record 16 of Set 12 | kapit
# Processing Record 17 of Set 12 | canora
# Processing Record 18 of Set 12 | inndyr
# Processing Record 19 of Set 12 | puerto leguizamo
# Processing Record 20 of Set 12 | siparia
# Processing Record 21 of Set 12 | skjaerhollen
# City not found. Skipping...
# Processing Record 22 of Set 12 | varsolt
# City not found. Skipping...
# Processing Record 23 of Set 12 | tanete
# Processing Record 24 of Set 12 | semnan
# Processing Record 25 of Set 12 | esperantina
# Processing Record 26 of Set 12 | baykit
# Processing Record 27 of Set 12 | manado
# Processing Record 28 of Set 12 | omboue
# Processing Record 29 of Set 12 | ayan
# Processing Record 30 of Set 12 | high level
# Processing Record 31 of Set 12 | belyy yar
# Processing Record 32 of Set 12 | saint andrews
# Processing Record 33 of Set 12 | ayagoz
# Processing Record 34 of Set 12 | buchanan
# Processing Record 35 of Set 12 | sovetskaya gavan
# Processing Record 36 of Set 12 | sankt veit
# Processing Record 37 of Set 12 | sisimiut
# Processing Record 38 of Set 12 | namatanai
# Processing Record 39 of Set 12 | goure
# Processing Record 40 of Set 12 | hanzhong
# Processing Record 41 of Set 12 | salta
# Processing Record 42 of Set 12 | itarema
# Processing Record 43 of Set 12 | toftir
# City not found. Skipping...
# Processing Record 44 of Set 12 | butembo
# Processing Record 45 of Set 12 | sao caetano de odivelas
# Processing Record 46 of Set 12 | qinhuangdao
# Processing Record 47 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 48 of Set 12 | portland
# Processing Record 49 of Set 12 | mabaruma
# Processing Record 50 of Set 12 | moron
# Processing Record 1 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 2 of Set 13 | kluang
# Processing Record 3 of Set 13 | ambon
# Processing Record 4 of Set 13 | loma alta
# Processing Record 5 of Set 13 | liangxiang
# Processing Record 6 of Set 13 | sompeta
# Processing Record 7 of Set 13 | sinnamary
# Processing Record 8 of Set 13 | asau
# Processing Record 9 of Set 13 | ostrovnoy
# Processing Record 10 of Set 13 | moussoro
# Processing Record 11 of Set 13 | tecate
# Processing Record 12 of Set 13 | taburi
# City not found. Skipping...
# Processing Record 13 of Set 13 | paysandu
# Processing Record 14 of Set 13 | cockburn town
# Processing Record 15 of Set 13 | guiglo
# Processing Record 16 of Set 13 | honiara
# Processing Record 17 of Set 13 | heihe
# Processing Record 18 of Set 13 | bundaberg
# Processing Record 19 of Set 13 | tarm
# Processing Record 20 of Set 13 | nushki
# Processing Record 21 of Set 13 | shashi
# Processing Record 22 of Set 13 | lahij
# Processing Record 23 of Set 13 | coffs harbour
# Processing Record 24 of Set 13 | port hedland
# Processing Record 25 of Set 13 | moree
# Processing Record 26 of Set 13 | bodden town
# Processing Record 27 of Set 13 | bondo
# Processing Record 28 of Set 13 | kampot
# Processing Record 29 of Set 13 | mayo
# Processing Record 30 of Set 13 | nyurba
# Processing Record 31 of Set 13 | aklavik
# Processing Record 32 of Set 13 | valls
# Processing Record 33 of Set 13 | kidal
# Processing Record 34 of Set 13 | sao lourenco do sul
# Processing Record 35 of Set 13 | cedar city
# Processing Record 36 of Set 13 | damaturu
# Processing Record 37 of Set 13 | haag
# Processing Record 38 of Set 13 | conceicao do araguaia
# Processing Record 39 of Set 13 | rabo de peixe
# Processing Record 40 of Set 13 | takoradi
# Processing Record 41 of Set 13 | skegness
# Processing Record 42 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 43 of Set 13 | oistins
# Processing Record 44 of Set 13 | pozo colorado
# Processing Record 45 of Set 13 | najran
# Processing Record 46 of Set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 47 of Set 13 | karaton
# Processing Record 48 of Set 13 | meulaboh
# Processing Record 49 of Set 13 | maymyo
# Processing Record 50 of Set 13 | kavieng
# Processing Record 1 of Set 14 | visnes
# Processing Record 2 of Set 14 | midyat
# Processing Record 3 of Set 14 | poya
# Processing Record 4 of Set 14 | balanacan
# Processing Record 5 of Set 14 | soe
# Processing Record 6 of Set 14 | hofn
# Processing Record 7 of Set 14 | kavaratti
# Processing Record 8 of Set 14 | coburg
# Processing Record 9 of Set 14 | svetlogorsk
# Processing Record 10 of Set 14 | verkhnetulomskiy
# Processing Record 11 of Set 14 | valdosta
# Processing Record 12 of Set 14 | ukiah
# Processing Record 13 of Set 14 | nome
# Processing Record 14 of Set 14 | severo-yeniseyskiy
# Processing Record 15 of Set 14 | mackenzie
# Processing Record 16 of Set 14 | lomovka
# Processing Record 17 of Set 14 | balimo
# City not found. Skipping...
# Processing Record 18 of Set 14 | boa vista
# Processing Record 19 of Set 14 | marzuq
# Processing Record 20 of Set 14 | mindelo
# Processing Record 21 of Set 14 | zolotonosha
# Processing Record 22 of Set 14 | namie
# Processing Record 23 of Set 14 | vila franca do campo
# Processing Record 24 of Set 14 | lakeside
# Processing Record 25 of Set 14 | flin flon
# Processing Record 26 of Set 14 | redlands
# Processing Record 27 of Set 14 | ngunguru
# Processing Record 28 of Set 14 | tubuala
# Processing Record 29 of Set 14 | genhe
# Processing Record 30 of Set 14 | klaeng
# Processing Record 31 of Set 14 | vila
# Processing Record 32 of Set 14 | gombong
# Processing Record 33 of Set 14 | ixtapa
# Processing Record 34 of Set 14 | kasongo
# Processing Record 35 of Set 14 | shahpur
# Processing Record 36 of Set 14 | zhetybay
# City not found. Skipping...
# Processing Record 37 of Set 14 | jalu
# Processing Record 38 of Set 14 | tarsus
# Processing Record 39 of Set 14 | dudinka
# Processing Record 40 of Set 14 | kachug
# Processing Record 41 of Set 14 | sarankhola
# Processing Record 42 of Set 14 | kukmor
# Processing Record 43 of Set 14 | kilindoni
# Processing Record 44 of Set 14 | waingapu
# Processing Record 45 of Set 14 | port moresby
# Processing Record 46 of Set 14 | cugir
# Processing Record 47 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 48 of Set 14 | ucluelet
# Processing Record 49 of Set 14 | carballo
# Processing Record 50 of Set 14 | andenes
# Processing Record 1 of Set 15 | khandagayty
# Processing Record 2 of Set 15 | husavik
# Processing Record 3 of Set 15 | nsanje
# Processing Record 4 of Set 15 | marsa matruh
# Processing Record 5 of Set 15 | rengali
# Processing Record 6 of Set 15 | camabatela
# Processing Record 7 of Set 15 | taoudenni
# Processing Record 8 of Set 15 | haapiti
# Processing Record 9 of Set 15 | stepnyak
# Processing Record 10 of Set 15 | astana
# Processing Record 11 of Set 15 | trairi
# Processing Record 12 of Set 15 | beyneu
# Processing Record 13 of Set 15 | doha
# Processing Record 14 of Set 15 | puerto madryn
# Processing Record 15 of Set 15 | labytnangi
# Processing Record 16 of Set 15 | lufilufi
# Processing Record 17 of Set 15 | port augusta
# Processing Record 18 of Set 15 | aktash
# Processing Record 19 of Set 15 | mazagao
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         College      US  64.8569 -147.8028     -2.25        77          75
# 1     Bandarbeyla      SO   9.4942   50.8122     75.31        62           0
# 2        Bilibino      RU  68.0546  166.4372    -29.29       100          94
# 3    Beringovskiy      RU  63.0500  179.3167      6.01        88         100
# 4  Saint-Philippe      RE -21.3585   55.7679     72.99        82          76
# 5         Rikitea      PF -23.1203 -134.9692     76.44        73           0
# 6         Cayenne      GF   4.9333  -52.3333     80.10        87          90
# 7     Yellowknife      CA  62.4560 -114.3525     -1.68        84          90
# 8           Vaini      TO -21.2000 -175.2000     86.16        79          20
# 9         Ushuaia      AR -54.8000  -68.3000     47.86        61          40
#
#    Wind Speed Current Description
# 0        0.00          light snow
# 1       14.18           clear sky
# 2        3.06     overcast clouds
# 3       13.98     overcast clouds
# 4       10.00       broken clouds
# 5       17.34           clear sky
# 6        1.99       moderate rain
# 7       10.36          light snow
# 8       11.50          few clouds
# 9       24.16          light rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
